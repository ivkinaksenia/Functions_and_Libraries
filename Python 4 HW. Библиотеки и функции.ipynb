# %% [markdown]
# # Домашнее задание Python-3. Работа с циклами и словарями

# %% [markdown]
# ### Задание 1. Функция для списка

# %%
##############################################   Задание 1.1   #################################################################


##### Создайте функцию function_for_list, которая на вход будет принимать список и с помощью функции print будет выдавать:
#######  1. Сумму элементов списка
#######  2. Максимальный элемент списка
#######  3. Минимальный элемент списка
#######  4. Длину списка
#######  5. Среднее значение списка

#####  Убедитесь, что все рассчитанные значения сохраняются во внутренние переменные (внутри функции) для дальнейших манипуляций
#####  Прогоните вашу функцию на списке lst = [1, 2, 3]

def function_for_list(lst): 
    print('сумма элементов списка -', sum(lst))
    print('максимальный элемент списка -', max(lst))
    print('минимальный эллемент списка -', min(lst))
    print('длина списка', len(lst))
    print('среднее значение списка -', sum(lst)/len(lst))

lst = [1, 2, 3]
function_for_list (lst)
# Out:
# сумма элементов списка - 6
# максимальный элемент списка - 3
# минимальный эллемент списка - 1
# длина списка 3
# среднее значение списка - 2.0

# %%
##############################################   Задание 1.2   #################################################################

#### Создайте внутри функции (в начале) счетчик, который подсчитывает количество не числовых элементов ряда
#### Добавьте в вашу функцию условие: если значение этого счетчика больше 0, то функция принтит "Нужны только цифры!"
#### В противном случае функция воспроизводит действия из пункта 1.1 (назовем их "основной командой")

#####  Прогоните вашу функцию на списках: 
lst1 = [1, 2, 3]
lst2 = [1, 2, 3, 'a']
lst3 = [1, 2, 3, '15']

def missing_checker(lst):
    counter=0
    for i in lst:
        if type(i) != int:
            counter+=1
            return 'Нужны только цифры!'  
    else: print('сумма элементов списка -', sum(lst)), print('максимальный элемент списка -', max(lst)),print('минимальный эллемент списка -', min(lst)),print('длина списка', len(lst)), print('среднее значение списка -', sum(lst)/len(lst))

missing_checker(lst1)
# Out:
# сумма элементов списка - 6
# максимальный элемент списка - 3
# минимальный эллемент списка - 1
# длина списка 3
# среднее значение списка - 2.0

# %%
missing_checker(lst2)
# Out:
# 'Нужны только цифры!'

# %%
missing_checker(lst3)
# Out:
# 'Нужны только цифры!'

# %%
##############################################   Задание 1.3   #################################################################

#### Создайте внутри функции условие, которое проверяет, превышает ли длина списка двойку
#### Добавьте в вашу функцию условие: если длина списка меньше либо равна двум, то функция принтит "Нужно как минимум три значения"
#### В противном случае функция воспроизводит "основную команду".
#### Код, добавленный в пункте 1.2, остается в самом начале функции

##### Подсказка: условие на длину списка будет внутренним условием относительно проверки на тип данных в списке

#####  Прогоните вашу функцию на списках: 
lst1 = [1, 2, 3]
lst2 = [1, 2, 3, 'a']
lst3 = [1, 2, 3, '15']
lst4 = [1, 2]
lst5 = ['a', 'b']

def missing_checker(lst):
    for i in lst:
        if type(i) != int:
            return 'Нужны только цифры!'
        if len(lst)<=2:
            return 'Нужно как минимум три значения'
    else: print('сумма элементов списка -', sum(lst)), print('максимальный элемент списка -', max(lst)),print('минимальный эллемент списка -', min(lst)),print('длина списка', len(lst)), print('среднее значение списка -', sum(lst)/len(lst))

missing_checker(lst1)
# Out:
# сумма элементов списка - 6
# максимальный элемент списка - 3
# минимальный эллемент списка - 1
# длина списка 3
# среднее значение списка - 2.0

# %%
missing_checker(lst2)
# Out:
# 'Нужны только цифры!'

# %%
missing_checker(lst3)
# Out:
# 'Нужны только цифры!'

# %%
missing_checker(lst4)
# Out:
# 'Нужно как минимум три значения'

# %%
missing_checker(lst5)
# Out:
# 'Нужны только цифры!'

# %% [markdown]
# ### Задание 2. Функция для словаря

# %%
##############################################   Задание 2.1   #################################################################


##### Создайте функцию function_for_dict, которая на вход будет принимать словарь и с помощью функции print будет выдавать:
#######  1. Количество элементов словаря
#######  2. Типы данных ключей словаря
#######  3. Сумму значений словаря (с помощью цикла, пробегающего по всем элементам словаря)

#####  Убедитесь, что рассчитанное значение сохраняется во внутреннюю переменную (внутри функции) для дальнейших манипуляций
#####  Прогоните вашу функцию на словарях: 
dct1 = {'Ivan':50000, 'Mary':75000, 'Michael': 64000, 'Anna':80000}
dct2 = {14:50000, 'Mary':75000, 64.99: 64000}

def function_for_dict(dct): 
    print('Количество элементов словаря',len(dct))
    print('Тип данных ключей словаря',type('dct.keys()'))
    print('Сумма значений словаря',sum(dct.values()))

function_for_dict(dct1)
# Out:
# Количество элементов словаря 4
# Тип данных ключей словаря <class 'str'>
# Сумма значений словаря 269000

# %%
function_for_dict(dct2)
# Out:
# Количество элементов словаря 3
# Тип данных ключей словаря <class 'str'>
# Сумма значений словаря 189000

# %%
##############################################   Задание 2.2   #################################################################

#### Создайте внутри функции (в начале) счетчик, который подсчитывает количество не строчных ключей словаря
#### Добавьте в вашу функцию условие: если значение этого счетчика больше 0, то функция принтит "Ключами должны быть имена!"
#### В противном случае функция воспроизводит действия из пункта 2.1 (назовем их "основной командой")

#####  Прогоните вашу функцию на словарях: 
dct1 = {'Ivan':45, 'Mary':38, 'Michael': 64, 'Anna':22}
dct2 = {15.65:45, 'Mary':38, 'Michael': 64, 'Anna':22}

def function_for_dict(dct): 
    counter=0
    for x in dct.keys():
        if type(x) != str:
            counter += 1
            if counter > 0:
                return 'Ключами должны быть имена!' 
    else:print('Количество элементов словаря',len(dct)),print('Тип данных ключей словаря',type('dct.keys()')),print('Сумма значений словаря',sum(dct.values()))
 
function_for_dict(dct1)
# Out:
# Количество элементов словаря 4
# Тип данных ключей словаря <class 'str'>
# Сумма значений словаря 169

# %%
function_for_dict(dct2)
# Out:
# 'Ключами должны быть имена!'

# %%
##############################################   Задание 2.3   #################################################################

#### Создайте внутри функции счетчик, который подсчитывает количество не цифровых значений словаря
#### Добавьте в вашу функцию условие: если есть не цифровые значения словаря, то функция принтит "Нужны числа в значениях!"
#### В противном случае функция воспроизводит "основную команду".Нужны числа в значениях!
#### Код, добавленный в пункте 2.2, остается в самом начале функции

##### Подсказка: условие на тип данных значений будет внутренним условием относительно проверки на тип данных ключей словаря.

#####  Прогоните вашу функцию на словарях: 
dct1 = {'Ivan':45, 'Mary':38, 'Michael': 64, 'Anna':22}
dct2 = {15.65:45, 'Mary':38, 'Michael': 64, 'Anna':22}
dct3 = {'Ivan':45, 'Mary':'Mary', 'Michael': 64, 'Anna':22}
dct4 = {15.65:45, 'Mary':38, 'Michael': 64, 'Anna':'22'}

def function_for_dict(dct): 
    counter1=0
    counter2=0
    for x in dct.keys():
        if type(x) != str:
            counter1 += 1
            if counter1 > 0:
                return 'Ключами должны быть имена!' 
    for x in dct.values():
        if type(x) != int:
            counter2+=1
            if counter2>0:
                return 'Нужны числа в значениях!'
    else:print('Количество элементов словаря',len(dct)),print('Тип данных ключей словаря',type('dct.keys()')),print('Сумма значений словаря',sum(dct.values()))
 
function_for_dict(dct1)
# Out:
# Количество элементов словаря 4
# Тип данных ключей словаря <class 'str'>
# Сумма значений словаря 169

# %%
function_for_dict(dct2)
# Out:
# Ключами должны быть имена!

# %%
function_for_dict(dct3)
# Out:
# Нужны числа в значениях!

# %%
function_for_dict(dct4)
# Out:
# Ключами должны быть имена!

# %% [markdown]
# ### Задание 3. Функция для алерта по метрикам

# %%
##############################################   Задание 3.1   #################################################################


##### Создайте функцию metric_alert, которая на вход будет принимать словарь с датами и значениями конверсии и будет:
#########    1. Определять среднее арифметическое значение метрики для всех дат в словаре (с помощью цикла) и принтить его
#########    2. Находить те значения метрик, которые больше чем на 10 процентных пунктов отличаются от общего среднего
#########    3. Принтить даты, соответствующие сильно отклоняющимся значениям метрики

######### Подсказка: Нужны значения метрик, которые отклоняются как вверх, так и вниз. 
#########            Можно использовать функцию abs (абсолютное значение, модуль)
#####  Прогоните вашу функцию на словаре: 
dict_metric = {'01.01.2021':0.46 , '01.02.2021':0.64, '01.03.2021':0.5, '01.04.2021':0.61 , 
                '01.05.2021':0.66 , '01.06.2021':0.4, '01.07.2021':0.32, '01.08.2021':0.66 ,
                 '01.09.2021':0.68 , '01.10.2021':0.54, '01.11.2021':0.57, '01.12.2021':0.59 }
#######
def metric_alert(dict_metric):
    avg = sum(dict_metric.values())/len(dict_metric.values())
    print('среднее значение',sum(dict_metric.values())/len(dict_metric.values()))
    for metric in dict_metric.values():
        if abs(metric - avg) > 0.10:
            print(metric)
       
metric_alert(dict_metric)
# Out:
# среднее значение 0.5525
# 0.66
# 0.4
# 0.32
# 0.66
# 0.68
